# %%
# !pip install plotly scikit-image scikit-learn
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2.0.2)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2025.12.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
import zipfile
with zipfile.ZipFile("data.zip", 'r') as zip_ref:
    zip_ref.extractall("data")

# %%
from glob import glob
import os

import numpy as np
import pandas as pd
import plotly.express as px
import skimage as ski

# %%
path = "./data/data/images/*/*.png"
file_paths = sorted(glob(path))

# %%
type_to_file = []
for file_path in file_paths:
    parts = os.path.normcase(file_path).split(os.sep)
    type_name = parts[-2]
    file_name = parts[-1]
    type_to_file.append({"type": type_name, "file": file_name})

type_to_file[:5]
# Out:
# [{'type': 'bug', 'file': '010.png'},
#  {'type': 'bug', 'file': '011.png'},
#  {'type': 'bug', 'file': '012.png'},
#  {'type': 'bug', 'file': '013.png'},
#  {'type': 'bug', 'file': '014.png'}]

# %%
image_list = [ski.io.imread(filename) for filename in file_paths]

# %%
for i, img in enumerate(image_list):
        # ski.transform.resize(img, (475, 475, 4))
    image_list[i] = ski.transform.resize(img, (128, 128, 4), preserve_range=True)

# %%
image_array = np.array(image_list, dtype=np.uint8)
image_array.shape
# Out:
# (1025, 128, 128, 4)

# %%
image_without_alpha_array = image_array[:, :, :, :3]
image_without_alpha_array.shape
# Out:
# (1025, 128, 128, 3)

# %%
image_without_alpha_flattened_array = image_without_alpha_array.reshape(image_without_alpha_array.shape[0], -1)
image_without_alpha_flattened_array.shape
# Out:
# (1025, 49152)

# %%
fig = px.imshow(
    image_without_alpha_array[0],
)
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a874c7e8-497d-4562-aa78-17839a1e2b97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a874c7e8-497d-4562-aa78-17839a1e2b97")) {                    Plotly.newPlot(                        "a874c7e8-497d-4562-aa78-17839a1e2b97",                        [{"name":"0","source":"...\u002fE3XrJc3lOHDu2ZMu2LKtSIkWxdxIkSILovS8W2+vd2+ZOOefLH3PvYrEEaYIEQeo9\u002fbAA7s6cOTPz\u002fc5XznfKJWbGT\u002fH+Qcw98FNcWfyUgPcZPyXgfYYx+5ef+oMrAyKa+XwBAQCUUkNDQ1rrOcevJMLnYzD+v9UehBAtLS1SytkH5xIwNDS0devWbDY75\u002fh7AoJhGNFkJJGM1zbVROPRZE3SjlqRmA2QW3ZL+VJ+Ol\u002fMl4q5Un6qUMo7gRew\u002fkmlJZPJPP\u002f88+3t7bMPziVAa53NZqempuYcv4wgQZGo3b6gdfn6nlXXLF+wtDOWiEnLYAIIRNDMvnaLfsEJSkoHWmvf83NThdGz4xMDU0dfPjnaO54bK\u002fhuMLfqDzzeaFrmEvDegYgi8UhrZ\u002fOmm67ectvmzgUdsWhMkGAwM\u002fsceMrzlBfoQBAsGSEiRxULXmHo+PDA63365HgNU2M6YsyrTd+7jkGv3L\u002f7xM5er+TNvdNPFK4EAUKKxraGbR+9bstt13Z2zksmEoYwAAptvACBQGwIGATB7ChWBGaPzu0cOvTw9k1afLajsXPNYtuQzMiWSn\u002f5yOH8Xcs++Tt3D50a2f\u002f00cPPncgO535CTdNbEWAbsi2TqI9ZBccdzDvTrn+pUZI0ZEtn0+333XT9hzY3NDQkrKQkIwwBmKG4oo8EIiIiQSQAFHLF\u002fS\u002fsG3hu1wbJv9Q9rykRE1JAqdAtZ0z5mQWtf\u002fvQsQEpOq\u002fqaF\u002fasvVnN+195NArP
fGRx4tR4cDq7qqNpYTQW2HW5CX\u002fo1FQpJYq2X99TF8vEhBSrblpazDpP\u002fuULH8DsBYUOLQQz9\u002fX1rVmzBuXiF69fvXV+vUEQBIsQJU4alDAN2zRJiPMsEIX9IwL7zK8PTn3jSN9+z6tf0tS9qcudds\u002ft76fh\u002fAppfHJxW3dt0paCCMxExOEdoXWgAtdXJcVlxWUmlxGEvYMZpgFf6\u002f5c6ane4d4aa+2nNzR21Z3eeTY1WP7ULWuXLWyORqJkNUKmmEhrDpQ62z\u002fyg6eeP14c6toy34wZKlDf\u002f4NH9z1++A3O4sqhpqZmz5498+bNm52OvjgBU1NTUVPevrjt7qUd7ZmEbQgBGISIQEoiZUrbNEjKMMisagNAxMx+oIcKTsELhBSs2ZLUGIvETUOEMSmDQ0vNWgWBGwSlgB3FZSaPETBrJgAMZoarVM71xxz3QDZ\u002fFoo70y3rOuYtazMMeWr76XXRzGc\u002fsiFumSABEYNZp2BpFkKQICJAaX3wRN9fP\u002fCgvTzesLA+N1742y9+d6x3YuZ9rzAujQAABMQtY2Fd6sbu1tXNmfZ0zDKkAdiEmETcoKghLUMKwyAhwVxxkQAuaLuVg2GDB2sVKDdQpUCXFBwNHwhCO8MItC76wUix3JcvDahg0GQ0J+oWNdTMr0nUxe2YbUqTQCeeP\u002fGRefPuvH6FIQgMzXz63MThkyMvvnpmKo9EItbaXLdpw4qr1\u002fRETHMyX\u002 ...

# %%
from sklearn.preprocessing import LabelEncoder

labels = [tf["type"] for tf in type_to_file]
le = LabelEncoder()
y = le.fit_transform(labels).reshape(-1, 1)
y.shape
# Out:
# (1025, 1)

# %%
labeled_data = np.hstack((image_without_alpha_flattened_array, y)).astype(np.uint8)
labeled_data.shape
# Out:
# (1025, 49153)

# %%
# %%time

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=2)
X_reduced = lda.fit_transform(labeled_data[:, :-1], y.reshape(-1))
# Out:
# CPU times: user 1min 6s, sys: 1.3 s, total: 1min 7s
# Wall time: 40.1 s

# %%
X_reduced
# Out:
# array([[-9.58686033e-02,  1.20279057e+00],
#        [ 8.78356656e-01,  9.39676675e-01],
#        [-3.35181580e-01,  1.74493794e+00],
#        ...,
#        [-5.67942705e+00,  2.58394931e+00],
#        [ 3.95149152e-04, -1.24434248e+00],
#        [ 2.66310077e+00, -1.52785558e+00]])

# %%
c = le.inverse_transform(labeled_data[:, -1].astype(int))
c
# Out:
# array(['bug', 'bug', 'bug', ..., 'water', 'water', 'water'], dtype='<U8')

# %%
lda_df = pd.DataFrame(X_reduced, columns=["LDA1", "LDA2"])
lda_df["Type"] = c
lda_df.head()
# Out:
#        LDA1      LDA2 Type
# 0 -0.095869  1.202791  bug
# 1  0.878357  0.939677  bug
# 2 -0.335182  1.744938  bug
# 3  1.091616  0.521894  bug
# 4  0.506635  2.055208  bug

# %%
fig = px.scatter(lda_df, x="LDA1", y="LDA2", color="Type")
# fig.update_layout(height=18 * 200)
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="42b75ea2-4767-4e31-b943-983bd2e1b9cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42b75ea2-4767-4e31-b943-983bd2e1b9cc")) {                    Plotly.newPlot(                        "42b75ea2-4767-4e31-b943-983bd2e1b9cc",                        [{"hovertemplate":"Type=bug\u003cbr\u003eLDA1=%{x}\u003cbr\u003eLDA2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"